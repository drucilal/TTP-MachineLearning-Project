# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %%
#import dataset
iowa_train = pd.read_csv('train.csv')
iowa_test = pd.read_csv('test.csv')

# %%
# LotFrontage vs. SalePrice
sns.scatterplot(x = 'LotFrontage', y = 'SalePrice', data = iowa_train)

# %%
# LotFrontage vs. logged SalePrice
sns.scatterplot(x = iowa_train.LotFrontage, y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# LotArea vs. SalePrice
sns.scatterplot(x = 'LotArea', y = 'SalePrice', data = iowa_train)

# %%
# LotArea vs. logged SalePrice
sns.scatterplot(x = 'LotArea', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# YearBuilt vs. SalePrice
sns.scatterplot(x = 'YearBuilt', y = 'SalePrice', data = iowa_train)

# %%
# YearBuilt vs. logged SalePrice
sns.scatterplot(x = 'YearBuilt', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# YearRemodAdd vs. SalePrice
sns.scatterplot(x = 'YearRemodAdd', y = 'SalePrice', data = iowa_train)

# %%
# YearRemodAdd vs. logged SalePrice
sns.scatterplot(x = 'YearRemodAdd', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# MasVnrArea vs. SalePrice
sns.scatterplot(x = 'MasVnrArea', y = 'SalePrice', data = iowa_train)

# %%
# MasVnrArea vs. logged SalePrice
sns.scatterplot(x = 'MasVnrArea', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# BsmtFinSF1 vs. SalePrice
sns.scatterplot(x = 'BsmtFinSF1', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFinSF1 vs. logged SalePrice
sns.scatterplot(x = 'BsmtFinSF1', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# BsmtFinSF2 vs. SalePrice
sns.scatterplot(x = 'BsmtFinSF2', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFinSF2 vs. logged SalePrice
sns.scatterplot(x = 'BsmtFinSF2', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged BsmtFinSF2 vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train.BsmtFinSF2), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# BsmtUnfSF vs. SalePrice
sns.scatterplot(x = 'BsmtUnfSF', y = 'SalePrice', data = iowa_train)

# %%
# BsmtUnfSF vs. logged SalePrice
sns.scatterplot(x = 'BsmtUnfSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# TotalBsmtSF vs. SalePrice
sns.scatterplot(x = 'TotalBsmtSF', y = 'SalePrice', data = iowa_train)

# %%
# TotalBsmtSF vs. logged SalePrice
sns.scatterplot(x = 'TotalBsmtSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# 1stFlrSF vs. SalePrice
sns.scatterplot(x = '1stFlrSF', y = 'SalePrice', data = iowa_train)

# %%
# 1stFlrSF vs. logged SalePrice
sns.scatterplot(x = '1stFlrSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# 2ndFlrSF vs. SalePrice
sns.scatterplot(x = '2ndFlrSF', y = 'SalePrice', data = iowa_train)

# %%
# 2ndFlrSF vs. logged SalePrice
sns.scatterplot(x = '2ndFlrSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged 2ndFlrSF vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train['2ndFlrSF']), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# logged 2ndFlrSF vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train['2ndFlrSF']), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# LowQualFinSF vs. SalePrice
sns.scatterplot(x = 'LowQualFinSF', y = 'SalePrice', data = iowa_train)

# %%
# LowQualFinSF vs. logged SalePrice
sns.scatterplot(x = 'LowQualFinSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged LowQualFinSF vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train.LowQualFinSF), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# GrLivArea vs. SalePrice
sns.scatterplot(x = 'GrLivArea', y = 'SalePrice', data = iowa_train)

# %%
# GrLivArea vs. logged SalePrice
sns.scatterplot(x = 'GrLivArea', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# GarageYrBlt vs. SalePrice
sns.scatterplot(x = 'GarageYrBlt', y = 'SalePrice', data = iowa_train)

# %%
# GarageYrBlt vs. logged SalePrice
sns.scatterplot(x = 'GarageYrBlt', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# GarageArea vs. SalePrice
sns.scatterplot(x = 'GarageArea', y = 'SalePrice', data = iowa_train)

# %%
# GarageArea vs. logged SalePrice
sns.scatterplot(x = 'GarageArea', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# WoodDeckSF vs. SalePrice
sns.scatterplot(x = 'WoodDeckSF', y = 'SalePrice', data = iowa_train)

# %%
# WoodDeckSF vs. logged SalePrice
sns.scatterplot(x = 'WoodDeckSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# OpenPorchSF vs. SalePrice
sns.scatterplot(x = 'OpenPorchSF', y = 'SalePrice', data = iowa_train)

# %%
# OpenPorchSF vs. logged SalePrice
sns.scatterplot(x = 'OpenPorchSF', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# EnclosedPorch vs. SalePrice
sns.scatterplot(x = 'EnclosedPorch', y = 'SalePrice', data = iowa_train)

# %%
# EnclosedPorch vs. logged SalePrice
sns.scatterplot(x = 'EnclosedPorch', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged EnclosedPorch vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train.EnclosedPorch), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# 3SsnPorch vs. SalePrice
sns.scatterplot(x = '3SsnPorch', y = 'SalePrice', data = iowa_train)

# %%
# 3SsnPorch vs. logged SalePrice
sns.scatterplot(x = '3SsnPorch', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged 3SsnPorch vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train['3SsnPorch']), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# ScreenPorch vs. SalePrice
sns.scatterplot(x = 'ScreenPorch', y = 'SalePrice', data = iowa_train)

# %%
# ScreenPorch vs. logged SalePrice
sns.scatterplot(x = 'ScreenPorch', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged ScreenPorch vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train.ScreenPorch), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# PoolArea vs. SalePrice
sns.scatterplot(x = 'PoolArea', y = 'SalePrice', data = iowa_train)

# %%
# PoolArea vs. logged SalePrice
sns.scatterplot(x = 'PoolArea', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
# logged PoolArea vs. logged SalePrice
sns.scatterplot(x = np.log(iowa_train.PoolArea), y = np.log(iowa_train.SalePrice), data = iowa_train)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log

# %%
# MiscVal vs. SalePrice
sns.scatterplot(x = 'LotFrontage', y = 'SalePrice', data = iowa_train)

# %%
# MiscVal vs. logged SalePrice
sns.scatterplot(x = 'LotFrontage', y = np.log(iowa_train.SalePrice), data = iowa_train)

# %%
#import packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %%
#import dataset
iowa_train = pd.read_csv('train.csv')
iowa_test = pd.read_csv('test.csv')

# %%
# MSSubClass vs. SalePrice
sns.scatterplot(x = 'MSSubClass', y = 'SalePrice', data = iowa_train)

# %%
# MSZoning vs. SalePrice
sns.scatterplot(x = 'MSZoning', y = 'SalePrice', data = iowa_train)

# %%
# LotFrontage vs. SalePrice
sns.scatterplot(x = 'LotFrontage', y = 'SalePrice', data = iowa_train)

# %%
# LotArea vs. SalePrice
sns.scatterplot(x = 'LotArea', y = 'SalePrice', data = iowa_train)

# %%
# Street vs. SalePrice
sns.scatterplot(x = 'Street', y = 'SalePrice', data = iowa_train)

# %%
# Alley vs. SalePrice
sns.scatterplot(x = 'Alley', y = 'SalePrice', data = iowa_train)

# %%
# LotShape vs. SalePrice
sns.scatterplot(x = 'LotShape', y = 'SalePrice', data = iowa_train)

# %%
# LandContour vs. SalePrice
sns.scatterplot(x = 'LandContour', y = 'SalePrice', data = iowa_train)

# %%
# Utilities vs. SalePrice
sns.scatterplot(x = 'Utilities', y = 'SalePrice', data = iowa_train)

# %%
# LotConfig vs. SalePrice
sns.scatterplot(x = 'LotConfig', y = 'SalePrice', data = iowa_train)

# %%
# LandSlope vs. SalePrice
sns.scatterplot(x = 'LandSlope', y = 'SalePrice', data = iowa_train)

# %%
# Neighborhood vs. SalePrice
sns.scatterplot(x = 'Neighborhood', y = 'SalePrice', data = iowa_train)

# %%
# Condition1 vs. SalePrice
sns.scatterplot(x = 'Condition1', y = 'SalePrice', data = iowa_train)

# %%
# Condition2 vs. SalePrice
sns.scatterplot(x = 'Condition2', y = 'SalePrice', data = iowa_train)

# %%
# BldgType vs. SalePrice
sns.scatterplot(x = 'BldgType', y = 'SalePrice', data = iowa_train)

# %%
# HouseStyle vs. SalePrice
sns.scatterplot(x = 'HouseStyle', y = 'SalePrice', data = iowa_train)

# %%
# OverallQual vs. SalePrice
sns.scatterplot(x = 'OverallQual', y = 'SalePrice', data = iowa_train)

# %%
# OverallCond vs. SalePrice
sns.scatterplot(x = 'OverallCond', y = 'SalePrice', data = iowa_train)

# %%
# YearBuilt vs. SalePrice
sns.scatterplot(x = 'YearBuilt', y = 'SalePrice', data = iowa_train)

# %%
# YearRemodAdd vs. SalePrice
sns.scatterplot(x = 'YearRemodAdd', y = 'SalePrice', data = iowa_train)

# %%
# RoofStyle vs. SalePrice
sns.scatterplot(x = 'RoofStyle', y = 'SalePrice', data = iowa_train)

# %%
# RoofMatl vs. SalePrice
sns.scatterplot(x = 'RoofMatl', y = 'SalePrice', data = iowa_train)

# %%
# Exterior1st vs. SalePrice
sns.scatterplot(x = 'Exterior1st', y = 'SalePrice', data = iowa_train)

# %%
# Exterior2nd vs. SalePrice
sns.scatterplot(x = 'Exterior2nd', y = 'SalePrice', data = iowa_train)

# %%
# MasVnrType vs. SalePrice
sns.scatterplot(x = 'MasVnrType', y = 'SalePrice', data = iowa_train)

# %%
# MasVnrArea vs. SalePrice
sns.scatterplot(x = 'MasVnrArea', y = 'SalePrice', data = iowa_train)

# %%
# ExterQual vs. SalePrice
sns.scatterplot(x = 'ExterQual', y = 'SalePrice', data = iowa_train)

# %%
# ExterCond vs. SalePrice
sns.scatterplot(x = 'ExterCond', y = 'SalePrice', data = iowa_train)

# %%
# Foundation vs. SalePrice
sns.scatterplot(x = 'Foundation', y = 'SalePrice', data = iowa_train)

# %%
# BsmtQual vs. SalePrice
sns.scatterplot(x = 'BsmtQual', y = 'SalePrice', data = iowa_train)

# %%
# BsmtCond vs. SalePrice
sns.scatterplot(x = 'BsmtCond', y = 'SalePrice', data = iowa_train)

# %%
# BsmtExposure vs. SalePrice
sns.scatterplot(x = 'BsmtExposure', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFinType1 vs. SalePrice
sns.scatterplot(x = 'BsmtFinType1', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFinSF1 vs. SalePrice
sns.scatterplot(x = 'BsmtFinSF1', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFinType2 vs. SalePrice
sns.scatterplot(x = 'BsmtFinType2', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFinSF2 vs. SalePrice
sns.scatterplot(x = 'BsmtFinSF2', y = 'SalePrice', data = iowa_train)

# %%
# BsmtUnfSF vs. SalePrice
sns.scatterplot(x = 'BsmtUnfSF', y = 'SalePrice', data = iowa_train)

# %%
# TotalBsmtSF vs. SalePrice
sns.scatterplot(x = 'TotalBsmtSF', y = 'SalePrice', data = iowa_train)

# %%
# Heating vs. SalePrice
sns.scatterplot(x = 'Heating', y = 'SalePrice', data = iowa_train)

# %%
# HeatingQC vs. SalePrice
sns.scatterplot(x = 'HeatingQC', y = 'SalePrice', data = iowa_train)

# %%
# CentralAir vs. SalePrice
sns.scatterplot(x = 'CentralAir', y = 'SalePrice', data = iowa_train)

# %%
# Electrical vs. SalePrice
sns.scatterplot(x = 'Electrical', y = 'SalePrice', data = iowa_train)

# %%
# 1stFlrSF vs. SalePrice
sns.scatterplot(x = '1stFlrSF', y = 'SalePrice', data = iowa_train)

# %%
# 2ndFlrSF vs. SalePrice
sns.scatterplot(x = '2ndFlrSF', y = 'SalePrice', data = iowa_train)

# %%
# LowQualFinSF vs. SalePrice
sns.scatterplot(x = 'LowQualFinSF', y = 'SalePrice', data = iowa_train)

# %%
# GrLivArea vs. SalePrice
sns.scatterplot(x = 'GrLivArea', y = 'SalePrice', data = iowa_train)

# %%
# BsmtFullBath vs. SalePrice
sns.scatterplot(x = 'BsmtFullBath', y = 'SalePrice', data = iowa_train)

# %%
# BsmtHalfBath vs. SalePrice
sns.scatterplot(x = 'BsmtHalfBath', y = 'SalePrice', data = iowa_train)

# %%
# fullbath vs. SalePrice
sns.scatterplot(x = 'FullBath', y = 'SalePrice', data = iowa_train)

# %%
# HalfBath vs. SalePrice
sns.scatterplot(x = 'HalfBath', y = 'SalePrice', data = iowa_train)

# %%
# BedroomAbvGr vs. SalePrice
sns.scatterplot(x = 'BedroomAbvGr', y = 'SalePrice', data = iowa_train)

# %%
# KitchenAbvGr vs. SalePrice
sns.scatterplot(x = 'KitchenAbvGr', y = 'SalePrice', data = iowa_train)

# %%
# KitchenQUal vs. SalePrice
sns.scatterplot(x = 'KitchenQual', y = 'SalePrice', data = iowa_train)

# %%
# TotRmsAbvGrd vs. SalePrice
sns.scatterplot(x = 'TotRmsAbvGrd', y = 'SalePrice', data = iowa_train)

# %%
# Functional vs. SalePrice
sns.scatterplot(x = 'Functional', y = 'SalePrice', data = iowa_train)

# %%
# Fireplaces vs. SalePrice
sns.scatterplot(x = 'Fireplaces', y = 'SalePrice', data = iowa_train)

# %%
# FireplaceQu vs. SalePrice
sns.scatterplot(x = 'FireplaceQu', y = 'SalePrice', data = iowa_train)

# %%
# GarageType vs. SalePrice
sns.scatterplot(x = 'GarageType', y = 'SalePrice', data = iowa_train)

# %%
# GarageYrBlt vs. SalePrice
sns.scatterplot(x = 'GarageYrBlt', y = 'SalePrice', data = iowa_train)

# %%
# GarageFinish vs. SalePrice
sns.scatterplot(x = 'GarageFinish', y = 'SalePrice', data = iowa_train)

# %%
# GarageCars vs. SalePrice
sns.scatterplot(x = 'GarageCars', y = 'SalePrice', data = iowa_train)

# %%
# GarageArea vs. SalePrice
sns.scatterplot(x = 'GarageArea', y = 'SalePrice', data = iowa_train)

# %%
# GarageQual vs. SalePrice
sns.scatterplot(x = 'GarageQual', y = 'SalePrice', data = iowa_train)

# %%
# GarageCond vs. SalePrice
sns.scatterplot(x = 'GarageCond', y = 'SalePrice', data = iowa_train)

# %%
# PavedDrive vs. SalePrice
sns.scatterplot(x = 'PavedDrive', y = 'SalePrice', data = iowa_train)

# %%
# WoodDeckSF vs. SalePrice
sns.scatterplot(x = 'WoodDeckSF', y = 'SalePrice', data = iowa_train)

# %%
# OpenPorchSF vs. SalePrice
sns.scatterplot(x = 'OpenPorchSF', y = 'SalePrice', data = iowa_train)

# %%
# EnclosedPorch vs. SalePrice
sns.scatterplot(x = 'EnclosedPorch', y = 'SalePrice', data = iowa_train)

# %%
# 3SsnPorch vs. SalePrice
sns.scatterplot(x = '3SsnPorch', y = 'SalePrice', data = iowa_train)

# %%
# ScreenPorch vs. SalePrice
sns.scatterplot(x = 'ScreenPorch', y = 'SalePrice', data = iowa_train)

# %%
# PoolArea vs. SalePrice
sns.scatterplot(x = 'PoolArea', y = 'SalePrice', data = iowa_train)

# %%
# PoolQC vs. SalePrice
sns.scatterplot(x = 'PoolQC', y = 'SalePrice', data = iowa_train)

# %%
# Fence vs. SalePrice
sns.scatterplot(x = 'Fence', y = 'SalePrice', data = iowa_train)

# %%
# MiscFeature vs. SalePrice
sns.scatterplot(x = 'MiscFeature', y = 'SalePrice', data = iowa_train)

# %%
# MiscVal vs. SalePrice
sns.scatterplot(x = 'LotFrontage', y = 'SalePrice', data = iowa_train)

# %%
# MoSold vs. SalePrice
sns.scatterplot(x = 'MoSold', y = 'SalePrice', data = iowa_train)

# %%
# YrSold vs. SalePrice
sns.scatterplot(x = 'YrSold', y = 'SalePrice', data = iowa_train)

# %%
# SaleType vs. SalePrice
sns.scatterplot(x = 'SaleType', y = 'SalePrice', data = iowa_train)

# %%
# SaleCondition vs. SalePrice
sns.scatterplot(x = 'SaleCondition', y = 'SalePrice', data = iowa_train)
